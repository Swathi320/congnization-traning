# %%
name=("swathi")
print(name)
email="swathichigurla6"
print(email)
# Out:
# swathi
# swathichigurla6

# %%
name=("sravani")
print(name)
# Out:
# sravani

# %%
city="pune"
print(city[3])
# Out:
# e

# %%
city="Pune"
print(city[-2])
# Out:
# n

# %%
name="swathi"
print(name[1:5])
# Out:
# wath

# %%
name="kavitha"
print(len(name))
# Out:
# 7

# %%
first="kavita"
second="yadav"
print(first+""+second)
# Out:
# kavitayadav

# %%
print("hello"*3)
# Out:
# hellohellohello

# %%
name="kavita"
print(name.upper())
# Out:
# KAVITA

# %%
name="SWATHI"
print(name.lower())
# Out:
# swathi

# %%
S="I Like Java"
print(s.replace("Java","Python"))
