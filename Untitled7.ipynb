# %%
print("Hello World")
# Out:
# Hello World

# %%
for i in range(8,16,24):
    print(i)
# Out:
# 8

# %%
t=(20,40,80,60,70)
print(len(t))
# Out:
# 5

# %%
t= (10,20,30,40,50)
print(t.index(30))
# Out:
# 2

# %%
t=(20,40,60) 
l=list(t)
print(l)
# Out:
# [20, 40, 60]

# %%
s={20,30,40,50}
print(s)
# Out:
# {40, 50, 20, 30}

# %% [markdown]
# s1={1,2,3}
# s2={3,4,5}
# print(s1.union(s2))

# %%
a = 10
b = 20
print("a, b =",a)
print("b =", b)
# Out:
# a, b = 10
# b = 20

# %%
x = 1
print(type(x))
# Out:
# <class 'int'>

# %%
lst = (1,3,3,6,8,8,2)\

new_list = list(set(lst))
print(new_list)
# Out:
# [1, 2, 3, 6, 8]

# %%
t = (10,20,30,40,60)
print (t.index(60))
# Out:
# 4

# %%
t = (1,2,3)
l = list(t)
print(l)
# Out:
# [1, 2, 3]

# %%
x = 10
print(type(x))
# Out:
# <class 'int'>

# %%
s = input("Enter string: ") 
print(s.replace(" "< ""))
# Out:
# Enter string:  56.5
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[57], line 2
#       1 s = input("Enter string: ")
# ----> 2 print(s.replace(" "< ""))
#
# TypeError: replace() takes at least 2 positional arguments (1 given)
