# %%
def numbers():
 yield 1
 yield 2
 yield 3
gen=numbers()
print(next(gen))
print(next(gen))
print(next(gen))
# Out:
# 1
# 2
# 3

# %%
file=open("demo.txt","w")
file.write("Hello student")
file.close()

# %%
file=open("demo.txt","r")
content=file.read()
print(content)
file.close()
# Out:
# Hello student

# %%
list=[1,2,3,4]
print(list[3])
# Out:
# 4

# %%
num=10
print(num/0)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[22], line 2
#       1 num=10
# ----> 2 print(num/0)
#
# ZeroDivisionError: division by zero

# %%
try:
    num=10
    print(num/0)
except ZeroDivisionError:
    print("cannot divide by zero")
# Out:
# cannot divide by zero

# %%
try:
     file=open("do.txt","r")
     content=file.read()
     print(content)
     file.close()
except :
     print("file not found")
# Out:
# file not found

# %%
try:
    file=open("demo,txt","r")
    content=file.read()
    priny(content)
    file.close()
except :
    print("file not found")
# Out:
# file not found

# %%
try:
    a=int(input("Enter the age:"))
except ValueError:
    print("it is not a integer")
# Out:
# Enter the age: 56.5
# it is not a integer

# %%
try:
    age=int(input("Enter the age:"))
except ValueError:
    print("Enter vaild age or around age")
# Out:
# Enter the age: 56.5
# Enter vaild age or around age

# %%
try:
     name=str(input("Enter your name"))
except nameError:
    print("write characters only")
# Out:
# Enter your name 76

# %%
try:
   num=int(input("Enter the Number"))
   print(10/num)1`
except ValueError:
      print("Enter the characters")
except ZeroDivisionError:
      print("Enter numbers not Zero")
# Out:
# Enter the Number 2
# 5.0
