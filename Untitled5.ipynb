# %%
def numbers():
 yield 1
 yield 2
 yield 3
gen=numbers()
print(next(gen))
print(next(gen))
print(next(gen))
# Out:
# 1
# 2
# 3

# %%
file=open("demo.txt","w")
file.write("Hello student")
file.close()

# %%
file=open("demo.txt","r")
content=file.read()
print(content)
file.close()
# Out:
# Hello student
