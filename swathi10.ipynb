# %%
import numpy as np
a=np.array(["Ram","Ravi","Suraj","Ankur"])
print(a[1],a[3])
# Out:
# Ravi Ankur

# %%
import numpy as np
arr=np.array([10,20,30,40,50])
print(arr[[1,3]])
# Out:
# [20 40]

# %%
Arr=np.array([10,20,30,40,50])
print(Arr[Arr>25])
# Out:
# [30 40 50]

# %%
marks=np.array([23,45,67,89,99])
print(marks[marks>35])
# Out:
# [45 67 89 99]

# %%
marks=np.array([11,23,45,41,19])
print(marks[marks>20])
# Out:
# [23 45 41]

# %%
arr=np.array([23,45,67,89,98])
for i in range(1,5):
     print(arr[i])
# Out:
# 45
# 67
# 89
# 98

# %%
for i in [10,20,30,440,]:
    print(i)
# Out:
# 10
# 20
# 30
# 440

# %%
arr=np.array([10,20,30,40,60,])
for i in arr:
    print(i)
# Out:
# 10
# 20
# 30
# 40
# 60

# %%
ar=np.array([[1,3,7,8,9],[4,5,8,7,2]])
for i in ar:
    print(i)
# Out:
# [1 3 7 8 9]
# [4 5 8 7 2]

# %%
mar=np.array([[20,30],[45,78,],[56,89]])
for i in mar:
    print(i)
# Out:
# [20 30]
# [45 78]
# [56 89]

# %%
import numpy as np
arr=np.array ([10,20,30,50,89,78,78,])
for i in np.nditer(arr):
      print(i)
# Out:
# 10
# 20
# 30
# 50
# 89
# 78
# 78

# %%
a=np.array(["swathi"])
b=np.array(["chigurla"])
print(a+" "+b)
# Out:
# ['swathi chigurla']

# %%
a=np.array([12,3,4,6])
b=np.array([3,5,7,8])
print(a,b)
# Out:
# [12  3  4  6] [3 5 7 8]

# %%
arr=np.array([10,20,30,40])
print(arr[2])
# Out:
# 30

# %%
arr=np.array([10,20,30,40,30,50])
x=np.where(arr==30)
print(x)
# Out:
# (array([2, 4]),)

# %%
arr=np.array([10,20,30,40])
result=sorted(arr)
print(result)
# Out:
# [np.int64(10), np.int64(20), np.int64(30), np.int64(40)]

# %%
a=np.array([10,30,20])
b=np.array([40,50,60])
c=np.concatenate([a,b])
print(c)
# Out:
# [10 30 20 40 50 60]

# %%
arr=np.array([20,4,5,6,8])
x=np.sort(arr)
print(x)
# Out:
# [ 4  5  6  8 20]

# %%
a=np.array([10,20,20])
b=np.array([40,50,60])
print(a+b)
# Out:
# [50 70 80]

# %%
marks=np.array([40,35,60,80,75])
print(marks[marks>=45])
# Out:
# [60 80 75]

# %%
a=np.array([11,33,55,66,99])
print(np.sum(a))
print(np.max(a))
print(np.min(a))
print(np.mean(a))
# Out:
# 264
# 99
# 11
# 52.8

# %%
a=np.array([5,6])
x=np.square(a*a)
print(x)
# Out:
# [ 625 1296]

# %%
print(np.power(arr,2))
# Out:
# [400  16  25  36  64]
