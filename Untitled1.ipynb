# %%
class Car:
    name = "BMW"
    colur= "blue"
    


car1=Car
print(Car1.name)
print(Car1.colour)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 8
#       3     colur= "blue"
#       7 car1=Car
# ----> 8 print(Car1.name)
#       9 print(Car1.colour)
#
# NameError: name 'Car1' is not defined

# %%
class Student: 
  def __int__(self,name,age):
    self.name=name
    self.age=age
    
s1 = Student("Swathi",20)
print(s1.name)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 6
#       3     self.name=name
#       4     self.age=age
# ----> 6 s1 = Student("Swathi",20)
#       7 print(s1.name)
#
# TypeError: Student() takes no arguments
