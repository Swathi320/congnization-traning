# %%
a=int(input("Enter the number:"))
print(a*a)
# Out:
# Enter the number: 5
# 25

# %%
def square(x):
  return x*x
print(square(5))
# Out:
# 25

# %%
square=lambda x:x*x
print(square(3))
# Out:
# 9

# %%
mul=lambda a,b:a*b
print(mul(5,3))
# Out:
# 15

# %%
check=lambda num:"Even" if num%2==0 else "odd"
print(check(6))
# Out:
# Even

# %%
students=[("Ram",80,),("ravi",87),("mahesh",55)]
result=sorted(students,key=lambda x:x[1])
print(result)
# Out:
# [('mahesh', 55), ('Ram', 80), ('ravi', 87)]

# %%
numbers=[1,2,3,4,5]
result=list(map(lambda x:x*x,numbers))
print(result)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[57], line 2
#       1 numbers=[1,2,3,4,5]
# ----> 2 result=list(map(lambda x:x*x,numbers))
#       3 print(result)
#
# TypeError: 'list' object is not callable

# %%
import numpy as np
numbers = [1,2,3,4,5]
result= numbers(filter(lambda num:num%2==0,numbers))  
print(result)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[56], line 3
#       1 import numpy as np
#       2 numbers = [1,2,3,4,5]
# ----> 3 result= numbers(filter(lambda num:num%2==0,numbers))
#       4 print(result)
#
# TypeError: 'list' object is not callable

# %%
from functools import reduce
number=[1,2,3,4,5]
result=reduce(lambda x,y:x+y,numbers)
print(numbers)
# Out:
# [1, 2, 3, 4, 5]
