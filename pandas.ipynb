# %%
import pandas as pd
marks=pd.Series([10,40,80,55,67])
print(marks)
# Out:
# 0    10
# 1    40
# 2    80
# 3    55
# 4    67
# dtype: int64

# %%
student_name=pd.Series(["Swathi","Roshni","Ankur"])
print(student_name)
# Out:
# 0    Swathi
# 1    Roshni
# 2     Ankur
# dtype: object

# %%
employee_salary=pd.Series([100000,200000,300000,400000,500000,700000])
print(employee_salary)
# Out:
# 0    100000
# 1    200000
# 2    300000
# 3    400000
# 4    500000
# 5    700000
# dtype: int64

# %%
T=(10,20,30,40,50)
a=pd.Series(T)
print(a)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
student={"kavita":90,
         "roshni":99
}
s=pd.Series(student)
print(s)
# Out:
# kavita    90
# roshni    99
# dtype: int64

# %%
i=pd.Series([100,200,300])
print(i)
# Out:
# 0    100
# 1    200
# 2    300
# dtype: int64

# %%
ci=pd.Series([100,200,300],
             index=["a","b","c"])
print(ci)
print(ci["b"])
print(ci[["a","c"]])
print(ci.index)
print(ci.values)
print(ci.dtype)
print(ci.size)
# Out:
# a    100
# b    200
# c    300
# dtype: int64
# 200
# a    100
# c    300
# dtype: int64
# Index(['a', 'b', 'c'], dtype='object')
# [100 200 300]
# int64
# 3

# %%
t=pd.Series((10,20,30))
print(t+10)
print(t*2)
# Out:
# 0    20
# 1    30
# 2    40
# dtype: int64
# 0    20
# 1    40
# 2    60
# dtype: int64

# %%
s=pd.Series([10,20,30,40])
print(s.sum())
print(s.max())
print(s.mean())
# Out:
# 100
# 40
# 25.0

# %%
s=pd.Series([10,30,29,46,55])
print([s>=30])
# Out:
# [0    False
# 1     True
# 2    False
# 3     True
# 4     True
# dtype: bool]

# %%
b=pd.Series([10,30,29,46,55])
print([b>20])
# Out:
# [0    False
# 1     True
# 2     True
# 3     True
# 4     True
# dtype: bool]

# %%
import numpy as np
s=pd.Series([10,20,30,np.nan,40])
print(s)
print(s.isnull())
print(s.isnull().sum())
print(s.fillna(0))
# Out:
# 0    10.0
# 1    20.0
# 2    30.0
# 3     NaN
# 4    40.0
# dtype: float64
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# dtype: bool
# 1
# 0    10.0
# 1    20.0
# 2    30.0
# 3     0.0
# 4    40.0
# dtype: float64

# %%
names=pd.Series(["kavita","roshni","ankur","raj","ramu","somu"])
print(names)
print(names.str.upper())
print(names.str.lower())
# Out:
# 0    kavita
# 1    roshni
# 2     ankur
# 3       raj
# 4      ramu
# 5      somu
# dtype: object
# 0    KAVITA
# 1    ROSHNI
# 2     ANKUR
# 3       RAJ
# 4      RAMU
# 5      SOMU
# dtype: object
# 0    kavita
# 1    roshni
# 2     ankur
# 3       raj
# 4      ramu
# 5      somu
# dtype: object

# %%
s=pd.Series([10,20,86,98,3,4,5])
print(s.sort_values())
print(s.sort_values(ascending=False))
# Out:
# 4     3
# 5     4
# 6     5
# 0    10
# 1    20
# 2    86
# 3    98
# dtype: int64
# 3    98
# 2    86
# 1    20
# 0    10
# 6     5
# 5     4
# 4     3
# dtype: int64

# %%
s=pd.Series([10,20,86,98,3,4,5,30,20,20,86,3])
print(s.unique())
print(s.value_counts())
# Out:
# [10 20 86 98  3  4  5 30]
# 20    3
# 86    2
# 3     2
# 10    1
# 98    1
# 4     1
# 5     1
# 30    1
# Name: count, dtype: int64

# %%
s=pd.Series([10,20,30,40])
print(s.tolist())
# Out:
# [10, 20, 30, 40]

# %%
s=pd.Series([10,20,30,np.nan,40,np.nan])
print(s.dropna())
# Out:
# 0    10.0
# 1    20.0
# 2    30.0
# 4    40.0
# dtype: float64

# %%
b=pd.Series([10,30,29,46,55])
print([b>40])
print(b[b>40]&b[b<53])
# Out:
# [0    False
# 1    False
# 2    False
# 3     True
# 4     True
# dtype: bool]
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# dtype: bool
# C:\Users\HP\AppData\Local\Temp\ipykernel_7936\1969926619.py:3: FutureWarning: Operation between Series with different indexes that are not of numpy boolean or object dtype will no longer return a numpy boolean result in a future version. Cast both Series to object type to maintain the prior behavior.
#   print(b[b>40]&b[b<53])

# %%
data={
       "name":["akshaya","srav","swathi","thashrin","sreeja"],
    "age":[19,20,20,18,20],
"city":["knr","hyd","knr","gdk","hyd"]
}
details=pd.DataFrame(data)
print(details)
print(details.shape)
print(details.columns)
# Out:
#        name  age city
# 0   akshaya   19  knr
# 1      srav   20  hyd
# 2    swathi   20  knr
# 3  thashrin   18  gdk
# 4    sreeja   20  hyd
# (5, 3)
# Index(['name', 'age', 'city'], dtype='object')

# %%
import pandas as pd
dataJoin=pd.DataFrame({
    "ID":[1,2,3],
    "Name":["abc","pqr","xyz"]})
print(dataJoin)
# Out:
#    ID Name
# 0   1  abc
# 1   2  pqr
# 2   3  xyz

# %%
dataJoin2=pd.DataFrame({
                "ID":[1,2,3],
    "marks":[10,20,30]})
print(dataJoin2)
# Out:
#    ID  marks
# 0   1     10
# 1   2     20
# 2   3     30

# %%
result=pd.merge(dataJoin,dataJoin2,on="ID")
print(result)
# Out:
#    ID Name  marks
# 0   1  abc     10
# 1   2  pqr     20
# 2   3  xyz     30
